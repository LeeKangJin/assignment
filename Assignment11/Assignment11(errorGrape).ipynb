# %% [markdown]
# # Assignment 11
#
#
# # 20135619 LeeKangJin
#
# # Git Link : https://github.com/LeeKangJin/assignment

# %% [markdown]
# # I've run four kinds of code and the error is as follows.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
case1 = 14.385199067108433 # std 0.1 , lamda 0.9
case2 = 12.694384673775838 # std 0.1 , lamda 0.1
case3 = 2.809529354466551  # std 0.9 , lamda 0.1
case4 = 13.731152233843183 # std 0.9 , lamda 0.9

x_case = [1,2,3,4]
y_case = [case1,case2,case3,case4]
plt.plot(x_case,y_case)
plt.show()

# %% [markdown]
# # In my case, case3 that std is 0.9(high) lamda 0.1(low) is best case.
